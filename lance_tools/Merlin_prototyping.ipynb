# %%
import merlin_spectra as ms
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#figuring out exactly why this takes so long is probably a good idea

# %%
linelist = ['H1 6562.80A', 'O1 1304.86A', 'O1 6300.30A', 'O2 3728.80A', 'O2 3726.10A',
            'O3 1660.81A', 'O3 1666.15A', 'O3 4363.21A', 'O3 4958.91A', 'O3 5006.84A',
            'He2 1640.41A', 'C2 1335.66A', 'C3 1906.68A', 'C3 1908.73A', 'C4 1549.00A',
            'Mg2 2795.53A', 'Mg2 2802.71A', 'Ne3 3868.76A', 'Ne3 3967.47A', 'N5 1238.82A',
            'N5 1242.80A', 'N4 1486.50A', 'N3 1749.67A', 'S2 6716.44A', 'S2 6730.82A',]
wavelength = [] #not finished
vs = ms.VisualizationManager(filename="/Users/lamoreau/python/ASpec/SimulationFiles/output_00273/info_rt_00273.txt", lines = linelist, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       1 linelist = ['H1 6562.80A', 'O1 1304.86A', 'O1 6300.30A', 'O2 3728.80A', 'O2 3726.10A',
#       2             'O3 1660.81A', 'O3 1666.15A', 'O3 4363.21A', 'O3 4958.91A', 'O3 5006.84A',
#       3             'He2 1640.41A', 'C2 1335.66A', 'C3 1906.68A', 'C3 1908.73A', 'C4 1549.00A',
#       4             'Mg2 2795.53A', 'Mg2 2802.71A', 'Ne3 3868.76A', 'Ne3 3967.47A', 'N5 1238.82A',
#       5             'N5 1242.80A', 'N4 1486.50A', 'N3 1749.67A', 'S2 6716.44A', 'S2 6730.82A',]
#       6 wavelength = [] #not finished
# ----> 7 vs = ms.VisualizationManager(filename="/Users/lamoreau/python/ASpec/SimulationFiles/output_00273/info_rt_00273.txt", lines = linelist, )
#
# TypeError: VisualizationManager.__init__() missing 1 required positional argument: 'wavelengths'

# %%
help(ms)
# Out:
# Help on package merlin_spectra:
#
# NAME
#     merlin_spectra
#
# PACKAGE CONTENTS
#     emission
#     galaxy_visualization
#     post
#
# CLASSES
#     builtins.object
#         merlin_spectra.emission.EmissionLineInterpolator
#         merlin_spectra.galaxy_visualization.VisualizationManager
#         merlin_spectra.post.SimulationPostAnalysis
#
#     class EmissionLineInterpolator(builtins.object)
#      |  EmissionLineInterpolator(filename: str, lines)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, filename: str, lines)
#      |      Initializes the interpolator with line list loaded from the given
#      |      filename/filepath.
#      |
#      |      Parameters:
#      |      -----------
#      |      filename (str): The name/path of the file to load the line emission
#      |      data from. This contains a text table. A commented (unread) header
#      |      displays the lines in the table. The next line (read) gives
# ...
