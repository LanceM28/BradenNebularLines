# %% [markdown]
# # Condensed Spec Notebook

# %%
# !git config --global user.name "LanceM28" 
# !git config --global git config --global user.email "lmoreau@terpmail.umd.edu"
# Out:
# usage: git config [<options>]
#
# Config file location
#     --global              use global config file
#     --system              use system config file
#     --local               use repository config file
#     --worktree            use per-worktree config file
#     -f, --file <file>     use given config file
#     --blob <blob-id>      read config from given blob object
#
# Action
#     --get                 get value: name [value-pattern]
#     --get-all             get all values: key [value-pattern]
#     --get-regexp          get values for regexp: name-regex [value-pattern]
#     --get-urlmatch        get value specific for the URL: section[.var] URL
#     --replace-all         replace all matching variables: name value [value-pattern]
#     --add                 add a new variable: name value
#     --unset               remove a variable: name [value-pattern]
#     --unset-all           remove all matches: name [value-pattern]
#     --rename-section      rename section: old-name new-name
#     --remove-section      remove a section: name
#     -l, --list            list all
#     --fixed-value         use string equality when comparing values to 'value-pattern'
#     -e, --edit            open an editor
#     --get-color           find the color configured: slot [default]
#     --get-colorbool       find the color setting: slot [stdout-is-tty]
#
# Type
#     -t, --type <type>     value is given this type
#     --bool                value is "true" or "false"
#     --int                 value is decimal number
#     --bool-or-int         value is --bool or --int
#     --bool-or-str         value is --bool or string
#     --path                value is a path (file or directory name)
#     --expiry-date         value is an expiry date
#
# Other
#     -z, --null            terminate values with NUL byte
#     --name-only           show variable names only
#     --includes            respect include directives on lookup
#     --show-origin         show origin of config (file, standard input, blob, command line)
#     --show-scope          show scope of config (worktree, local, global, system, command)
#     --default <value>     with --get, use default value when missing entry

# %%
#initialization

import numpy as np
import matplotlib.pyplot as plt
import yt
import os
from yt.funcs import mylog
mylog.setLevel(10) #has to do something with what errors get stored?

cell_fields = [
    "Density",
    "x-velocity",
    "y-velocity",
    "z-velocity",
    "Pressure",
    "Metallicity",
    # "dark_matter_density",
    "xHI",
    "xHII",
    "xHeII",
    "xHeIII",
]
'''Defining the field names given in the simulaiton to be loaded
Is this dynamic? is this more like a call or more like a label
'''
epf = [
    ("particle_family", "b"),
    ("particle_tag", "b"),
    ("particle_birth_epoch", "d"),
    ("particle_metallicity", "d"),
]
'''
Set up additional value slots for particles, 
allowing us to then hold the spectroscopic values we want in particles.
'''
# Out:
# '\nSet up additional value slots for particles, \nallowing us to then hold the spectroscopic values we want in particles.\n'

# %%
from BradenNebularLines import emission

# %%
'''
cell_fields = [
    "Density",
    "x-velocity",
    "y-velocity",
    "z-velocity",
    "Pressure",
    "Metallicity",
    # "dark_matter_density",
    "xHI",
    "xHII",
    "xHeII",
    "xHeIII",
]
epf = [
    ("particle_family", "b"),
    ("particle_tag", "b"),
    ("particle_birth_epoch", "d"),
    ("particle_metallicity", "d"),
]
'''

# Cloudy Grid Run Bounds (log values)
# Umin, Umax, Ustep: -6.0 1.0 0.5
# Nmin, Nmax, Nstep: -1.0 6.0 0.5 
# Tmin, Tmax, Tstop: 3.0 6.0 0.1

lines=["H1_6562.80A","O1_1304.86A","O1_6300.30A","O2_3728.80A","O2_3726.10A","O3_1660.81A",
       "O3_1666.15A","O3_4363.21A","O3_4958.91A","O3_5006.84A", "He2_1640.41A","C2_1335.66A",
       "C3_1906.68A","C3_1908.73A","C4_1549.00A","Mg2_2795.53A","Mg2_2802.71A","Ne3_3868.76A",
       "Ne3_3967.47A","N5_1238.82A","N5_1242.80A","N4_1486.50A","N3_1749.67A","S2_6716.44A","S2_6730.82A"]

# Ionization Parameter Field
# Based on photon densities bins 1-4
# Should not include bin 1 -> Lyman Werner non-ionizing
# TODO check ionization parameter
def _ion_param(field, data): 
    from yt.frontends.ramses.field_handlers import RTFieldFileHandler
    p = RTFieldFileHandler.get_rt_parameters(ds).copy()
    p.update(ds.parameters)

    cgs_c = 2.99792458e10     #light velocity
    pd_2 = data['ramses-rt','Photon_density_2']*p["unit_pf"]/cgs_c #physical photon number density in cm-3
    pd_3 = data['ramses-rt','Photon_density_3']*p["unit_pf"]/cgs_c
    pd_4 = data['ramses-rt','Photon_density_4']*p["unit_pf"]/cgs_c

    photon = pd_2 + pd_3 + pd_4

    return photon/data['gas', 'number_density']  

# Temporarily testing rt fields
def _ion_param2(field, data): 
    from yt.frontends.ramses.field_handlers import RTFieldFileHandler
    p = RTFieldFileHandler.get_rt_parameters(ds).copy() # grabbing simulation parameters, is this grabbing constants?
    p.update(ds.parameters)

    cgs_c =  2.99792458e10     #light velocity
    pd_2 = data['rt','photon_density_2']#*p["unit_pf"]/cgs_c #physical photon number density in cm-3
    pd_3 = data['rt','photon_density_3']#*p["unit_pf"]/cgs_c
    pd_4 = data['rt','photon_density_4']#*p["unit_pf"]/cgs_c

    photon = pd_2 + pd_3 + pd_4

    return photon/data['gas', 'number_density']*data['gas', 'number_density']/data['gas', 'number_density']

yt.add_field(
    ('gas', 'ion-param'), 
    function=_ion_param, 
    sampling_type="cell", 
    units="cm**3", #this is how units are defined for added fields
    force_override=True
)

yt.add_field(
    ('gas', 'ion-param2'), 
    function=_ion_param2, 
    sampling_type="cell", 
    units="1", 
    force_override=True
)

# True divides emissions by density squared in interpolator
### Why set to true???
dens_normalized = True
if dens_normalized: 
    units = '1/cm**6'
else:
    units = '1'

# Add intensity fields for all lines in the list
for i in range(len(lines)):
    yt.add_field(
        #('gas', 'intensity_' + lines[i] + '_[erg_cm^{-2}_s^{-1}]'),
        ('gas', 'intensity_' + lines[i]),
        function=emission.get_line_emission(i, dens_normalized),
        sampling_type='cell',
        units=units,
        force_override=True
    )

yt.add_field(
        ('gas', 'intensity_halpha_norm'),
        function=emission.get_line_emission(0, True),
        sampling_type='cell',
        units='1/cm**6',
        force_override=True
)

yt.add_field(
        ('gas', 'intensity_oiii_norm'),
        function=emission.get_line_emission(9, True),
        sampling_type='cell',
        units='1/cm**6',
        force_override=True
)

f1 = "/Users/lamoreau/python/Aether Spectroscopy/output_00273"

ds = yt.load(f1, extra_particle_fields = epf)
ad = ds.all_data()

# For projections in a spherical region
sp = ds.sphere([0.49118094, 0.49275361, 0.49473726], (2000, "pc"))
sp2 = ds.sphere([0.49118094, 0.49275361, 0.49473726], (4000, "pc"))
sp3 = ds.sphere([0.49118094, 0.49275361, 0.49473726], (700, "pc"))

ds.fields
# Out:
# yt : [INFO     ] 2025-03-11 00:04:25,626 Parameters: current_time              = 4.311420483661945
# yt : [INFO     ] 2025-03-11 00:04:25,627 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2025-03-11 00:04:25,630 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-11 00:04:25,632 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-11 00:04:25,633 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2025-03-11 00:04:25,634 Parameters: current_redshift          = 12.171087046255657
# yt : [INFO     ] 2025-03-11 00:04:25,635 Parameters: omega_lambda              = 0.685000002384186
# yt : [INFO     ] 2025-03-11 00:04:25,637 Parameters: omega_matter              = 0.314999997615814
# yt : [INFO     ] 2025-03-11 00:04:25,638 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2025-03-11 00:04:25,639 Parameters: hubble_constant           = 0.674000015258789
# yt : [DEBUG    ] 2025-03-11 00:04:25,649 Initializing data storage.
# yt : [DEBUG    ] 2025-03-11 00:04:25,650 Setting up domain geometry.
# yt : [DEBUG    ] 2025-03-11 00:04:25,651 Initializing Octree Geometry Handler.
# yt : [DEBUG    ] 2025-03-11 00:04:25,657 Detected fluid type gravity in domain_id=1
# yt : [DEBUG    ] 2025-03-11 00:04:25,661 Detected fluid type ramses-rt in domain_id=1
# yt : [DEBUG    ] 2025-03-11 00:04:25,663 Not reading photon group properties
# yt : [DEBUG    ] 2025-03-11 00:04:25,665 Detected fluid type ramses in domain_id=1
# yt : [DEBUG    ] 2025-03-11 00:04:25,667 Reading hydro file descriptor.
# yt : [DEBUG    ] 2025-03-11 00:04:25,669 Reading fluid file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/hydro_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:25,670 Detected particle type sink in domain_id=1
# yt : [DEBUG    ] 2025-03-11 00:04:25,673 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:25,674 Detected particle type io in domain_id=1
# yt : [DEBUG    ] 2025-03-11 00:04:25,684 Reading domain AMR    1 (9.446e+04, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:25,849 Detected fluid type gravity in domain_id=2
# yt : [DEBUG    ] 2025-03-11 00:04:25,850 Detected fluid type ramses-rt in domain_id=2
# yt : [DEBUG    ] 2025-03-11 00:04:25,851 Detected fluid type ramses in domain_id=2
# yt : [DEBUG    ] 2025-03-11 00:04:25,852 Detected particle type sink in domain_id=2
# yt : [DEBUG    ] 2025-03-11 00:04:25,853 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:25,854 Detected particle type io in domain_id=2
# yt : [DEBUG    ] 2025-03-11 00:04:25,861 Reading domain AMR    2 (7.917e+04, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:25,928 Detected fluid type gravity in domain_id=3
# yt : [DEBUG    ] 2025-03-11 00:04:25,929 Detected fluid type ramses-rt in domain_id=3
# yt : [DEBUG    ] 2025-03-11 00:04:25,929 Detected fluid type ramses in domain_id=3
# yt : [DEBUG    ] 2025-03-11 00:04:25,930 Detected particle type sink in domain_id=3
# yt : [DEBUG    ] 2025-03-11 00:04:25,931 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:25,932 Detected particle type io in domain_id=3
# yt : [DEBUG    ] 2025-03-11 00:04:25,939 Reading domain AMR    3 (4.202e+04, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:25,996 Detected fluid type gravity in domain_id=4
# yt : [DEBUG    ] 2025-03-11 00:04:25,997 Detected fluid type ramses-rt in domain_id=4
# yt : [DEBUG    ] 2025-03-11 00:04:25,997 Detected fluid type ramses in domain_id=4
# yt : [DEBUG    ] 2025-03-11 00:04:25,998 Detected particle type sink in domain_id=4
# yt : [DEBUG    ] 2025-03-11 00:04:26,000 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,001 Detected particle type io in domain_id=4
# yt : [DEBUG    ] 2025-03-11 00:04:26,003 Reading domain AMR    4 (6.510e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,023 Detected fluid type gravity in domain_id=5
# yt : [DEBUG    ] 2025-03-11 00:04:26,024 Detected fluid type ramses-rt in domain_id=5
# yt : [DEBUG    ] 2025-03-11 00:04:26,025 Detected fluid type ramses in domain_id=5
# yt : [DEBUG    ] 2025-03-11 00:04:26,025 Detected particle type sink in domain_id=5
# yt : [DEBUG    ] 2025-03-11 00:04:26,027 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,027 Detected particle type io in domain_id=5
# yt : [DEBUG    ] 2025-03-11 00:04:26,029 Reading domain AMR    5 (8.500e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,044 Detected fluid type gravity in domain_id=6
# yt : [DEBUG    ] 2025-03-11 00:04:26,045 Detected fluid type ramses-rt in domain_id=6
# yt : [DEBUG    ] 2025-03-11 00:04:26,046 Detected fluid type ramses in domain_id=6
# yt : [DEBUG    ] 2025-03-11 00:04:26,047 Detected particle type sink in domain_id=6
# yt : [DEBUG    ] 2025-03-11 00:04:26,048 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,049 Detected particle type io in domain_id=6
# yt : [DEBUG    ] 2025-03-11 00:04:26,051 Reading domain AMR    6 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,064 Detected fluid type gravity in domain_id=7
# yt : [DEBUG    ] 2025-03-11 00:04:26,065 Detected fluid type ramses-rt in domain_id=7
# yt : [DEBUG    ] 2025-03-11 00:04:26,065 Detected fluid type ramses in domain_id=7
# yt : [DEBUG    ] 2025-03-11 00:04:26,066 Detected particle type sink in domain_id=7
# yt : [DEBUG    ] 2025-03-11 00:04:26,067 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,068 Detected particle type io in domain_id=7
# yt : [DEBUG    ] 2025-03-11 00:04:26,070 Reading domain AMR    7 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,084 Detected fluid type gravity in domain_id=8
# yt : [DEBUG    ] 2025-03-11 00:04:26,085 Detected fluid type ramses-rt in domain_id=8
# yt : [DEBUG    ] 2025-03-11 00:04:26,085 Detected fluid type ramses in domain_id=8
# yt : [DEBUG    ] 2025-03-11 00:04:26,086 Detected particle type sink in domain_id=8
# yt : [DEBUG    ] 2025-03-11 00:04:26,088 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,089 Detected particle type io in domain_id=8
# yt : [DEBUG    ] 2025-03-11 00:04:26,091 Reading domain AMR    8 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,104 Detected fluid type gravity in domain_id=9
# yt : [DEBUG    ] 2025-03-11 00:04:26,105 Detected fluid type ramses-rt in domain_id=9
# yt : [DEBUG    ] 2025-03-11 00:04:26,106 Detected fluid type ramses in domain_id=9
# yt : [DEBUG    ] 2025-03-11 00:04:26,106 Detected particle type sink in domain_id=9
# yt : [DEBUG    ] 2025-03-11 00:04:26,108 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,109 Detected particle type io in domain_id=9
# yt : [DEBUG    ] 2025-03-11 00:04:26,110 Reading domain AMR    9 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,124 Detected fluid type gravity in domain_id=10
# yt : [DEBUG    ] 2025-03-11 00:04:26,125 Detected fluid type ramses-rt in domain_id=10
# yt : [DEBUG    ] 2025-03-11 00:04:26,125 Detected fluid type ramses in domain_id=10
# yt : [DEBUG    ] 2025-03-11 00:04:26,126 Detected particle type sink in domain_id=10
# yt : [DEBUG    ] 2025-03-11 00:04:26,127 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,128 Detected particle type io in domain_id=10
# yt : [DEBUG    ] 2025-03-11 00:04:26,129 Reading domain AMR   10 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,145 Detected fluid type gravity in domain_id=11
# yt : [DEBUG    ] 2025-03-11 00:04:26,146 Detected fluid type ramses-rt in domain_id=11
# yt : [DEBUG    ] 2025-03-11 00:04:26,146 Detected fluid type ramses in domain_id=11
# yt : [DEBUG    ] 2025-03-11 00:04:26,147 Detected particle type sink in domain_id=11
# yt : [DEBUG    ] 2025-03-11 00:04:26,198 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,211 Detected particle type io in domain_id=11
# yt : [DEBUG    ] 2025-03-11 00:04:26,213 Reading domain AMR   11 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,248 Detected fluid type gravity in domain_id=12
# yt : [DEBUG    ] 2025-03-11 00:04:26,250 Detected fluid type ramses-rt in domain_id=12
# yt : [DEBUG    ] 2025-03-11 00:04:26,252 Detected fluid type ramses in domain_id=12
# yt : [DEBUG    ] 2025-03-11 00:04:26,255 Detected particle type sink in domain_id=12
# yt : [DEBUG    ] 2025-03-11 00:04:26,258 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,260 Detected particle type io in domain_id=12
# yt : [DEBUG    ] 2025-03-11 00:04:26,264 Reading domain AMR   12 (3.205e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,290 Detected fluid type gravity in domain_id=13
# yt : [DEBUG    ] 2025-03-11 00:04:26,291 Detected fluid type ramses-rt in domain_id=13
# yt : [DEBUG    ] 2025-03-11 00:04:26,292 Detected fluid type ramses in domain_id=13
# yt : [DEBUG    ] 2025-03-11 00:04:26,293 Detected particle type sink in domain_id=13
# yt : [DEBUG    ] 2025-03-11 00:04:26,295 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,296 Detected particle type io in domain_id=13
# yt : [DEBUG    ] 2025-03-11 00:04:26,300 Reading domain AMR   13 (2.652e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,324 Detected fluid type gravity in domain_id=14
# yt : [DEBUG    ] 2025-03-11 00:04:26,326 Detected fluid type ramses-rt in domain_id=14
# yt : [DEBUG    ] 2025-03-11 00:04:26,327 Detected fluid type ramses in domain_id=14
# yt : [DEBUG    ] 2025-03-11 00:04:26,328 Detected particle type sink in domain_id=14
# yt : [DEBUG    ] 2025-03-11 00:04:26,330 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,331 Detected particle type io in domain_id=14
# yt : [DEBUG    ] 2025-03-11 00:04:26,333 Reading domain AMR   14 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,468 Detected fluid type gravity in domain_id=15
# yt : [DEBUG    ] 2025-03-11 00:04:26,469 Detected fluid type ramses-rt in domain_id=15
# yt : [DEBUG    ] 2025-03-11 00:04:26,470 Detected fluid type ramses in domain_id=15
# yt : [DEBUG    ] 2025-03-11 00:04:26,471 Detected particle type sink in domain_id=15
# yt : [DEBUG    ] 2025-03-11 00:04:26,485 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,486 Detected particle type io in domain_id=15
# yt : [DEBUG    ] 2025-03-11 00:04:26,488 Reading domain AMR   15 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,505 Detected fluid type gravity in domain_id=16
# yt : [DEBUG    ] 2025-03-11 00:04:26,506 Detected fluid type ramses-rt in domain_id=16
# yt : [DEBUG    ] 2025-03-11 00:04:26,507 Detected fluid type ramses in domain_id=16
# yt : [DEBUG    ] 2025-03-11 00:04:26,509 Detected particle type sink in domain_id=16
# yt : [DEBUG    ] 2025-03-11 00:04:26,510 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,513 Detected particle type io in domain_id=16
# yt : [DEBUG    ] 2025-03-11 00:04:26,515 Reading domain AMR   16 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,531 Detected fluid type gravity in domain_id=17
# yt : [DEBUG    ] 2025-03-11 00:04:26,532 Detected fluid type ramses-rt in domain_id=17
# yt : [DEBUG    ] 2025-03-11 00:04:26,533 Detected fluid type ramses in domain_id=17
# yt : [DEBUG    ] 2025-03-11 00:04:26,534 Detected particle type sink in domain_id=17
# yt : [DEBUG    ] 2025-03-11 00:04:26,536 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,537 Detected particle type io in domain_id=17
# yt : [DEBUG    ] 2025-03-11 00:04:26,539 Reading domain AMR   17 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,554 Detected fluid type gravity in domain_id=18
# yt : [DEBUG    ] 2025-03-11 00:04:26,555 Detected fluid type ramses-rt in domain_id=18
# yt : [DEBUG    ] 2025-03-11 00:04:26,556 Detected fluid type ramses in domain_id=18
# yt : [DEBUG    ] 2025-03-11 00:04:26,556 Detected particle type sink in domain_id=18
# yt : [DEBUG    ] 2025-03-11 00:04:26,558 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,559 Detected particle type io in domain_id=18
# yt : [DEBUG    ] 2025-03-11 00:04:26,561 Reading domain AMR   18 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,576 Detected fluid type gravity in domain_id=19
# yt : [DEBUG    ] 2025-03-11 00:04:26,577 Detected fluid type ramses-rt in domain_id=19
# yt : [DEBUG    ] 2025-03-11 00:04:26,577 Detected fluid type ramses in domain_id=19
# yt : [DEBUG    ] 2025-03-11 00:04:26,579 Detected particle type sink in domain_id=19
# yt : [DEBUG    ] 2025-03-11 00:04:26,580 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,581 Detected particle type io in domain_id=19
# yt : [DEBUG    ] 2025-03-11 00:04:26,583 Reading domain AMR   19 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,598 Detected fluid type gravity in domain_id=20
# yt : [DEBUG    ] 2025-03-11 00:04:26,599 Detected fluid type ramses-rt in domain_id=20
# yt : [DEBUG    ] 2025-03-11 00:04:26,600 Detected fluid type ramses in domain_id=20
# yt : [DEBUG    ] 2025-03-11 00:04:26,601 Detected particle type sink in domain_id=20
# yt : [DEBUG    ] 2025-03-11 00:04:26,603 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,604 Detected particle type io in domain_id=20
# yt : [DEBUG    ] 2025-03-11 00:04:26,606 Reading domain AMR   20 (3.317e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,626 Detected fluid type gravity in domain_id=21
# yt : [DEBUG    ] 2025-03-11 00:04:26,627 Detected fluid type ramses-rt in domain_id=21
# yt : [DEBUG    ] 2025-03-11 00:04:26,628 Detected fluid type ramses in domain_id=21
# yt : [DEBUG    ] 2025-03-11 00:04:26,630 Detected particle type sink in domain_id=21
# yt : [DEBUG    ] 2025-03-11 00:04:26,631 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,632 Detected particle type io in domain_id=21
# yt : [DEBUG    ] 2025-03-11 00:04:26,634 Reading domain AMR   21 (5.140e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,656 Detected fluid type gravity in domain_id=22
# yt : [DEBUG    ] 2025-03-11 00:04:26,657 Detected fluid type ramses-rt in domain_id=22
# yt : [DEBUG    ] 2025-03-11 00:04:26,657 Detected fluid type ramses in domain_id=22
# yt : [DEBUG    ] 2025-03-11 00:04:26,658 Detected particle type sink in domain_id=22
# yt : [DEBUG    ] 2025-03-11 00:04:26,660 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,660 Detected particle type io in domain_id=22
# yt : [DEBUG    ] 2025-03-11 00:04:26,662 Reading domain AMR   22 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,678 Detected fluid type gravity in domain_id=23
# yt : [DEBUG    ] 2025-03-11 00:04:26,679 Detected fluid type ramses-rt in domain_id=23
# yt : [DEBUG    ] 2025-03-11 00:04:26,679 Detected fluid type ramses in domain_id=23
# yt : [DEBUG    ] 2025-03-11 00:04:26,680 Detected particle type sink in domain_id=23
# yt : [DEBUG    ] 2025-03-11 00:04:26,682 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,683 Detected particle type io in domain_id=23
# yt : [DEBUG    ] 2025-03-11 00:04:26,684 Reading domain AMR   23 (1.636e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,703 Detected fluid type gravity in domain_id=24
# yt : [DEBUG    ] 2025-03-11 00:04:26,704 Detected fluid type ramses-rt in domain_id=24
# yt : [DEBUG    ] 2025-03-11 00:04:26,705 Detected fluid type ramses in domain_id=24
# yt : [DEBUG    ] 2025-03-11 00:04:26,706 Detected particle type sink in domain_id=24
# yt : [DEBUG    ] 2025-03-11 00:04:26,707 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,708 Detected particle type io in domain_id=24
# yt : [DEBUG    ] 2025-03-11 00:04:26,710 Reading domain AMR   24 (2.544e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,730 Detected fluid type gravity in domain_id=25
# yt : [DEBUG    ] 2025-03-11 00:04:26,731 Detected fluid type ramses-rt in domain_id=25
# yt : [DEBUG    ] 2025-03-11 00:04:26,732 Detected fluid type ramses in domain_id=25
# yt : [DEBUG    ] 2025-03-11 00:04:26,733 Detected particle type sink in domain_id=25
# yt : [DEBUG    ] 2025-03-11 00:04:26,736 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,737 Detected particle type io in domain_id=25
# yt : [DEBUG    ] 2025-03-11 00:04:26,739 Reading domain AMR   25 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,755 Detected fluid type gravity in domain_id=26
# yt : [DEBUG    ] 2025-03-11 00:04:26,756 Detected fluid type ramses-rt in domain_id=26
# yt : [DEBUG    ] 2025-03-11 00:04:26,757 Detected fluid type ramses in domain_id=26
# yt : [DEBUG    ] 2025-03-11 00:04:26,759 Detected particle type sink in domain_id=26
# yt : [DEBUG    ] 2025-03-11 00:04:26,763 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,765 Detected particle type io in domain_id=26
# yt : [DEBUG    ] 2025-03-11 00:04:26,767 Reading domain AMR   26 (1.312e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,786 Detected fluid type gravity in domain_id=27
# yt : [DEBUG    ] 2025-03-11 00:04:26,787 Detected fluid type ramses-rt in domain_id=27
# yt : [DEBUG    ] 2025-03-11 00:04:26,788 Detected fluid type ramses in domain_id=27
# yt : [DEBUG    ] 2025-03-11 00:04:26,789 Detected particle type sink in domain_id=27
# yt : [DEBUG    ] 2025-03-11 00:04:26,790 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,791 Detected particle type io in domain_id=27
# yt : [DEBUG    ] 2025-03-11 00:04:26,796 Reading domain AMR   27 (2.216e+04, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,909 Detected fluid type gravity in domain_id=28
# yt : [DEBUG    ] 2025-03-11 00:04:26,910 Detected fluid type ramses-rt in domain_id=28
# yt : [DEBUG    ] 2025-03-11 00:04:26,910 Detected fluid type ramses in domain_id=28
# yt : [DEBUG    ] 2025-03-11 00:04:26,911 Detected particle type sink in domain_id=28
# yt : [DEBUG    ] 2025-03-11 00:04:26,914 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,915 Detected particle type io in domain_id=28
# yt : [DEBUG    ] 2025-03-11 00:04:26,922 Reading domain AMR   28 (3.029e+04, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:26,972 Detected fluid type gravity in domain_id=29
# yt : [DEBUG    ] 2025-03-11 00:04:26,973 Detected fluid type ramses-rt in domain_id=29
# yt : [DEBUG    ] 2025-03-11 00:04:26,973 Detected fluid type ramses in domain_id=29
# yt : [DEBUG    ] 2025-03-11 00:04:26,974 Detected particle type sink in domain_id=29
# yt : [DEBUG    ] 2025-03-11 00:04:26,975 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:26,976 Detected particle type io in domain_id=29
# yt : [DEBUG    ] 2025-03-11 00:04:26,981 Reading domain AMR   29 (1.750e+04, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,014 Detected fluid type gravity in domain_id=30
# yt : [DEBUG    ] 2025-03-11 00:04:27,015 Detected fluid type ramses-rt in domain_id=30
# yt : [DEBUG    ] 2025-03-11 00:04:27,015 Detected fluid type ramses in domain_id=30
# yt : [DEBUG    ] 2025-03-11 00:04:27,016 Detected particle type sink in domain_id=30
# yt : [DEBUG    ] 2025-03-11 00:04:27,017 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,018 Detected particle type io in domain_id=30
# yt : [DEBUG    ] 2025-03-11 00:04:27,019 Reading domain AMR   30 (2.049e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,037 Detected fluid type gravity in domain_id=31
# yt : [DEBUG    ] 2025-03-11 00:04:27,038 Detected fluid type ramses-rt in domain_id=31
# yt : [DEBUG    ] 2025-03-11 00:04:27,038 Detected fluid type ramses in domain_id=31
# yt : [DEBUG    ] 2025-03-11 00:04:27,039 Detected particle type sink in domain_id=31
# yt : [DEBUG    ] 2025-03-11 00:04:27,040 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,041 Detected particle type io in domain_id=31
# yt : [DEBUG    ] 2025-03-11 00:04:27,042 Reading domain AMR   31 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,058 Detected fluid type gravity in domain_id=32
# yt : [DEBUG    ] 2025-03-11 00:04:27,059 Detected fluid type ramses-rt in domain_id=32
# yt : [DEBUG    ] 2025-03-11 00:04:27,060 Detected fluid type ramses in domain_id=32
# yt : [DEBUG    ] 2025-03-11 00:04:27,061 Detected particle type sink in domain_id=32
# yt : [DEBUG    ] 2025-03-11 00:04:27,062 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,064 Detected particle type io in domain_id=32
# yt : [DEBUG    ] 2025-03-11 00:04:27,066 Reading domain AMR   32 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,082 Detected fluid type gravity in domain_id=33
# yt : [DEBUG    ] 2025-03-11 00:04:27,083 Detected fluid type ramses-rt in domain_id=33
# yt : [DEBUG    ] 2025-03-11 00:04:27,083 Detected fluid type ramses in domain_id=33
# yt : [DEBUG    ] 2025-03-11 00:04:27,084 Detected particle type sink in domain_id=33
# yt : [DEBUG    ] 2025-03-11 00:04:27,086 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,087 Detected particle type io in domain_id=33
# yt : [DEBUG    ] 2025-03-11 00:04:27,089 Reading domain AMR   33 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,105 Detected fluid type gravity in domain_id=34
# yt : [DEBUG    ] 2025-03-11 00:04:27,106 Detected fluid type ramses-rt in domain_id=34
# yt : [DEBUG    ] 2025-03-11 00:04:27,106 Detected fluid type ramses in domain_id=34
# yt : [DEBUG    ] 2025-03-11 00:04:27,107 Detected particle type sink in domain_id=34
# yt : [DEBUG    ] 2025-03-11 00:04:27,109 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,110 Detected particle type io in domain_id=34
# yt : [DEBUG    ] 2025-03-11 00:04:27,111 Reading domain AMR   34 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,129 Detected fluid type gravity in domain_id=35
# yt : [DEBUG    ] 2025-03-11 00:04:27,130 Detected fluid type ramses-rt in domain_id=35
# yt : [DEBUG    ] 2025-03-11 00:04:27,130 Detected fluid type ramses in domain_id=35
# yt : [DEBUG    ] 2025-03-11 00:04:27,132 Detected particle type sink in domain_id=35
# yt : [DEBUG    ] 2025-03-11 00:04:27,133 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,134 Detected particle type io in domain_id=35
# yt : [DEBUG    ] 2025-03-11 00:04:27,136 Reading domain AMR   35 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,152 Detected fluid type gravity in domain_id=36
# yt : [DEBUG    ] 2025-03-11 00:04:27,153 Detected fluid type ramses-rt in domain_id=36
# yt : [DEBUG    ] 2025-03-11 00:04:27,154 Detected fluid type ramses in domain_id=36
# yt : [DEBUG    ] 2025-03-11 00:04:27,155 Detected particle type sink in domain_id=36
# yt : [DEBUG    ] 2025-03-11 00:04:27,157 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,158 Detected particle type io in domain_id=36
# yt : [DEBUG    ] 2025-03-11 00:04:27,160 Reading domain AMR   36 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,177 Detected fluid type gravity in domain_id=37
# yt : [DEBUG    ] 2025-03-11 00:04:27,178 Detected fluid type ramses-rt in domain_id=37
# yt : [DEBUG    ] 2025-03-11 00:04:27,179 Detected fluid type ramses in domain_id=37
# yt : [DEBUG    ] 2025-03-11 00:04:27,180 Detected particle type sink in domain_id=37
# yt : [DEBUG    ] 2025-03-11 00:04:27,185 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,190 Detected particle type io in domain_id=37
# yt : [DEBUG    ] 2025-03-11 00:04:27,193 Reading domain AMR   37 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,211 Detected fluid type gravity in domain_id=38
# yt : [DEBUG    ] 2025-03-11 00:04:27,213 Detected fluid type ramses-rt in domain_id=38
# yt : [DEBUG    ] 2025-03-11 00:04:27,213 Detected fluid type ramses in domain_id=38
# yt : [DEBUG    ] 2025-03-11 00:04:27,214 Detected particle type sink in domain_id=38
# yt : [DEBUG    ] 2025-03-11 00:04:27,217 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,220 Detected particle type io in domain_id=38
# yt : [DEBUG    ] 2025-03-11 00:04:27,224 Reading domain AMR   38 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,244 Detected fluid type gravity in domain_id=39
# yt : [DEBUG    ] 2025-03-11 00:04:27,245 Detected fluid type ramses-rt in domain_id=39
# yt : [DEBUG    ] 2025-03-11 00:04:27,246 Detected fluid type ramses in domain_id=39
# yt : [DEBUG    ] 2025-03-11 00:04:27,247 Detected particle type sink in domain_id=39
# yt : [DEBUG    ] 2025-03-11 00:04:27,248 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,251 Detected particle type io in domain_id=39
# yt : [DEBUG    ] 2025-03-11 00:04:27,253 Reading domain AMR   39 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,274 Detected fluid type gravity in domain_id=40
# yt : [DEBUG    ] 2025-03-11 00:04:27,274 Detected fluid type ramses-rt in domain_id=40
# yt : [DEBUG    ] 2025-03-11 00:04:27,275 Detected fluid type ramses in domain_id=40
# yt : [DEBUG    ] 2025-03-11 00:04:27,276 Detected particle type sink in domain_id=40
# yt : [DEBUG    ] 2025-03-11 00:04:27,278 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,279 Detected particle type io in domain_id=40
# yt : [DEBUG    ] 2025-03-11 00:04:27,280 Reading domain AMR   40 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,300 Detected fluid type gravity in domain_id=41
# yt : [DEBUG    ] 2025-03-11 00:04:27,301 Detected fluid type ramses-rt in domain_id=41
# yt : [DEBUG    ] 2025-03-11 00:04:27,302 Detected fluid type ramses in domain_id=41
# yt : [DEBUG    ] 2025-03-11 00:04:27,304 Detected particle type sink in domain_id=41
# yt : [DEBUG    ] 2025-03-11 00:04:27,306 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,308 Detected particle type io in domain_id=41
# yt : [DEBUG    ] 2025-03-11 00:04:27,311 Reading domain AMR   41 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,392 Detected fluid type gravity in domain_id=42
# yt : [DEBUG    ] 2025-03-11 00:04:27,392 Detected fluid type ramses-rt in domain_id=42
# yt : [DEBUG    ] 2025-03-11 00:04:27,393 Detected fluid type ramses in domain_id=42
# yt : [DEBUG    ] 2025-03-11 00:04:27,404 Detected particle type sink in domain_id=42
# yt : [DEBUG    ] 2025-03-11 00:04:27,407 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,408 Detected particle type io in domain_id=42
# yt : [DEBUG    ] 2025-03-11 00:04:27,410 Reading domain AMR   42 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,428 Detected fluid type gravity in domain_id=43
# yt : [DEBUG    ] 2025-03-11 00:04:27,429 Detected fluid type ramses-rt in domain_id=43
# yt : [DEBUG    ] 2025-03-11 00:04:27,430 Detected fluid type ramses in domain_id=43
# yt : [DEBUG    ] 2025-03-11 00:04:27,431 Detected particle type sink in domain_id=43
# yt : [DEBUG    ] 2025-03-11 00:04:27,432 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,433 Detected particle type io in domain_id=43
# yt : [DEBUG    ] 2025-03-11 00:04:27,435 Reading domain AMR   43 (3.510e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,453 Detected fluid type gravity in domain_id=44
# yt : [DEBUG    ] 2025-03-11 00:04:27,453 Detected fluid type ramses-rt in domain_id=44
# yt : [DEBUG    ] 2025-03-11 00:04:27,454 Detected fluid type ramses in domain_id=44
# yt : [DEBUG    ] 2025-03-11 00:04:27,455 Detected particle type sink in domain_id=44
# yt : [DEBUG    ] 2025-03-11 00:04:27,457 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,459 Detected particle type io in domain_id=44
# yt : [DEBUG    ] 2025-03-11 00:04:27,462 Reading domain AMR   44 (4.137e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,490 Detected fluid type gravity in domain_id=45
# yt : [DEBUG    ] 2025-03-11 00:04:27,491 Detected fluid type ramses-rt in domain_id=45
# yt : [DEBUG    ] 2025-03-11 00:04:27,491 Detected fluid type ramses in domain_id=45
# yt : [DEBUG    ] 2025-03-11 00:04:27,493 Detected particle type sink in domain_id=45
# yt : [DEBUG    ] 2025-03-11 00:04:27,494 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,495 Detected particle type io in domain_id=45
# yt : [DEBUG    ] 2025-03-11 00:04:27,497 Reading domain AMR   45 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,516 Detected fluid type gravity in domain_id=46
# yt : [DEBUG    ] 2025-03-11 00:04:27,518 Detected fluid type ramses-rt in domain_id=46
# yt : [DEBUG    ] 2025-03-11 00:04:27,518 Detected fluid type ramses in domain_id=46
# yt : [DEBUG    ] 2025-03-11 00:04:27,520 Detected particle type sink in domain_id=46
# yt : [DEBUG    ] 2025-03-11 00:04:27,522 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,524 Detected particle type io in domain_id=46
# yt : [DEBUG    ] 2025-03-11 00:04:27,526 Reading domain AMR   46 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,545 Detected fluid type gravity in domain_id=47
# yt : [DEBUG    ] 2025-03-11 00:04:27,546 Detected fluid type ramses-rt in domain_id=47
# yt : [DEBUG    ] 2025-03-11 00:04:27,547 Detected fluid type ramses in domain_id=47
# yt : [DEBUG    ] 2025-03-11 00:04:27,549 Detected particle type sink in domain_id=47
# yt : [DEBUG    ] 2025-03-11 00:04:27,551 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,552 Detected particle type io in domain_id=47
# yt : [DEBUG    ] 2025-03-11 00:04:27,554 Reading domain AMR   47 (1.396e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,577 Detected fluid type gravity in domain_id=48
# yt : [DEBUG    ] 2025-03-11 00:04:27,578 Detected fluid type ramses-rt in domain_id=48
# yt : [DEBUG    ] 2025-03-11 00:04:27,579 Detected fluid type ramses in domain_id=48
# yt : [DEBUG    ] 2025-03-11 00:04:27,580 Detected particle type sink in domain_id=48
# yt : [DEBUG    ] 2025-03-11 00:04:27,583 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,584 Detected particle type io in domain_id=48
# yt : [DEBUG    ] 2025-03-11 00:04:27,587 Reading domain AMR   48 (1.437e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,611 Detected fluid type gravity in domain_id=49
# yt : [DEBUG    ] 2025-03-11 00:04:27,612 Detected fluid type ramses-rt in domain_id=49
# yt : [DEBUG    ] 2025-03-11 00:04:27,613 Detected fluid type ramses in domain_id=49
# yt : [DEBUG    ] 2025-03-11 00:04:27,614 Detected particle type sink in domain_id=49
# yt : [DEBUG    ] 2025-03-11 00:04:27,615 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,617 Detected particle type io in domain_id=49
# yt : [DEBUG    ] 2025-03-11 00:04:27,620 Reading domain AMR   49 (2.120e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,643 Detected fluid type gravity in domain_id=50
# yt : [DEBUG    ] 2025-03-11 00:04:27,644 Detected fluid type ramses-rt in domain_id=50
# yt : [DEBUG    ] 2025-03-11 00:04:27,645 Detected fluid type ramses in domain_id=50
# yt : [DEBUG    ] 2025-03-11 00:04:27,646 Detected particle type sink in domain_id=50
# yt : [DEBUG    ] 2025-03-11 00:04:27,648 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,649 Detected particle type io in domain_id=50
# yt : [DEBUG    ] 2025-03-11 00:04:27,653 Reading domain AMR   50 (5.344e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,683 Detected fluid type gravity in domain_id=51
# yt : [DEBUG    ] 2025-03-11 00:04:27,684 Detected fluid type ramses-rt in domain_id=51
# yt : [DEBUG    ] 2025-03-11 00:04:27,685 Detected fluid type ramses in domain_id=51
# yt : [DEBUG    ] 2025-03-11 00:04:27,687 Detected particle type sink in domain_id=51
# yt : [DEBUG    ] 2025-03-11 00:04:27,691 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,693 Detected particle type io in domain_id=51
# yt : [DEBUG    ] 2025-03-11 00:04:27,696 Reading domain AMR   51 (3.533e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,724 Detected fluid type gravity in domain_id=52
# yt : [DEBUG    ] 2025-03-11 00:04:27,725 Detected fluid type ramses-rt in domain_id=52
# yt : [DEBUG    ] 2025-03-11 00:04:27,725 Detected fluid type ramses in domain_id=52
# yt : [DEBUG    ] 2025-03-11 00:04:27,726 Detected particle type sink in domain_id=52
# yt : [DEBUG    ] 2025-03-11 00:04:27,728 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,729 Detected particle type io in domain_id=52
# yt : [DEBUG    ] 2025-03-11 00:04:27,736 Reading domain AMR   52 (3.037e+04, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,845 Detected fluid type gravity in domain_id=53
# yt : [DEBUG    ] 2025-03-11 00:04:27,845 Detected fluid type ramses-rt in domain_id=53
# yt : [DEBUG    ] 2025-03-11 00:04:27,846 Detected fluid type ramses in domain_id=53
# yt : [DEBUG    ] 2025-03-11 00:04:27,847 Detected particle type sink in domain_id=53
# yt : [DEBUG    ] 2025-03-11 00:04:27,848 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,849 Detected particle type io in domain_id=53
# yt : [DEBUG    ] 2025-03-11 00:04:27,855 Reading domain AMR   53 (2.330e+04, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:27,901 Detected fluid type gravity in domain_id=54
# yt : [DEBUG    ] 2025-03-11 00:04:27,902 Detected fluid type ramses-rt in domain_id=54
# yt : [DEBUG    ] 2025-03-11 00:04:27,902 Detected fluid type ramses in domain_id=54
# yt : [DEBUG    ] 2025-03-11 00:04:27,903 Detected particle type sink in domain_id=54
# yt : [DEBUG    ] 2025-03-11 00:04:27,905 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:27,906 Detected particle type io in domain_id=54
# yt : [DEBUG    ] 2025-03-11 00:04:27,910 Reading domain AMR   54 (8.211e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,093 Detected fluid type gravity in domain_id=55
# yt : [DEBUG    ] 2025-03-11 00:04:28,094 Detected fluid type ramses-rt in domain_id=55
# yt : [DEBUG    ] 2025-03-11 00:04:28,094 Detected fluid type ramses in domain_id=55
# yt : [DEBUG    ] 2025-03-11 00:04:28,095 Detected particle type sink in domain_id=55
# yt : [DEBUG    ] 2025-03-11 00:04:28,097 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,098 Detected particle type io in domain_id=55
# yt : [DEBUG    ] 2025-03-11 00:04:28,103 Reading domain AMR   55 (1.905e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,128 Detected fluid type gravity in domain_id=56
# yt : [DEBUG    ] 2025-03-11 00:04:28,129 Detected fluid type ramses-rt in domain_id=56
# yt : [DEBUG    ] 2025-03-11 00:04:28,130 Detected fluid type ramses in domain_id=56
# yt : [DEBUG    ] 2025-03-11 00:04:28,131 Detected particle type sink in domain_id=56
# yt : [DEBUG    ] 2025-03-11 00:04:28,133 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,133 Detected particle type io in domain_id=56
# yt : [DEBUG    ] 2025-03-11 00:04:28,135 Reading domain AMR   56 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,152 Detected fluid type gravity in domain_id=57
# yt : [DEBUG    ] 2025-03-11 00:04:28,153 Detected fluid type ramses-rt in domain_id=57
# yt : [DEBUG    ] 2025-03-11 00:04:28,153 Detected fluid type ramses in domain_id=57
# yt : [DEBUG    ] 2025-03-11 00:04:28,154 Detected particle type sink in domain_id=57
# yt : [DEBUG    ] 2025-03-11 00:04:28,155 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,156 Detected particle type io in domain_id=57
# yt : [DEBUG    ] 2025-03-11 00:04:28,160 Reading domain AMR   57 (3.289e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,181 Detected fluid type gravity in domain_id=58
# yt : [DEBUG    ] 2025-03-11 00:04:28,182 Detected fluid type ramses-rt in domain_id=58
# yt : [DEBUG    ] 2025-03-11 00:04:28,183 Detected fluid type ramses in domain_id=58
# yt : [DEBUG    ] 2025-03-11 00:04:28,184 Detected particle type sink in domain_id=58
# yt : [DEBUG    ] 2025-03-11 00:04:28,185 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,186 Detected particle type io in domain_id=58
# yt : [DEBUG    ] 2025-03-11 00:04:28,188 Reading domain AMR   58 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,204 Detected fluid type gravity in domain_id=59
# yt : [DEBUG    ] 2025-03-11 00:04:28,205 Detected fluid type ramses-rt in domain_id=59
# yt : [DEBUG    ] 2025-03-11 00:04:28,206 Detected fluid type ramses in domain_id=59
# yt : [DEBUG    ] 2025-03-11 00:04:28,206 Detected particle type sink in domain_id=59
# yt : [DEBUG    ] 2025-03-11 00:04:28,208 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,209 Detected particle type io in domain_id=59
# yt : [DEBUG    ] 2025-03-11 00:04:28,211 Reading domain AMR   59 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,227 Detected fluid type gravity in domain_id=60
# yt : [DEBUG    ] 2025-03-11 00:04:28,228 Detected fluid type ramses-rt in domain_id=60
# yt : [DEBUG    ] 2025-03-11 00:04:28,229 Detected fluid type ramses in domain_id=60
# yt : [DEBUG    ] 2025-03-11 00:04:28,230 Detected particle type sink in domain_id=60
# yt : [DEBUG    ] 2025-03-11 00:04:28,232 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,233 Detected particle type io in domain_id=60
# yt : [DEBUG    ] 2025-03-11 00:04:28,234 Reading domain AMR   60 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,250 Detected fluid type gravity in domain_id=61
# yt : [DEBUG    ] 2025-03-11 00:04:28,251 Detected fluid type ramses-rt in domain_id=61
# yt : [DEBUG    ] 2025-03-11 00:04:28,252 Detected fluid type ramses in domain_id=61
# yt : [DEBUG    ] 2025-03-11 00:04:28,253 Detected particle type sink in domain_id=61
# yt : [DEBUG    ] 2025-03-11 00:04:28,254 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,255 Detected particle type io in domain_id=61
# yt : [DEBUG    ] 2025-03-11 00:04:28,257 Reading domain AMR   61 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,272 Detected fluid type gravity in domain_id=62
# yt : [DEBUG    ] 2025-03-11 00:04:28,273 Detected fluid type ramses-rt in domain_id=62
# yt : [DEBUG    ] 2025-03-11 00:04:28,273 Detected fluid type ramses in domain_id=62
# yt : [DEBUG    ] 2025-03-11 00:04:28,274 Detected particle type sink in domain_id=62
# yt : [DEBUG    ] 2025-03-11 00:04:28,275 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,276 Detected particle type io in domain_id=62
# yt : [DEBUG    ] 2025-03-11 00:04:28,278 Reading domain AMR   62 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,294 Detected fluid type gravity in domain_id=63
# yt : [DEBUG    ] 2025-03-11 00:04:28,295 Detected fluid type ramses-rt in domain_id=63
# yt : [DEBUG    ] 2025-03-11 00:04:28,296 Detected fluid type ramses in domain_id=63
# yt : [DEBUG    ] 2025-03-11 00:04:28,297 Detected particle type sink in domain_id=63
# yt : [DEBUG    ] 2025-03-11 00:04:28,298 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,299 Detected particle type io in domain_id=63
# yt : [DEBUG    ] 2025-03-11 00:04:28,301 Reading domain AMR   63 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,318 Detected fluid type gravity in domain_id=64
# yt : [DEBUG    ] 2025-03-11 00:04:28,319 Detected fluid type ramses-rt in domain_id=64
# yt : [DEBUG    ] 2025-03-11 00:04:28,319 Detected fluid type ramses in domain_id=64
# yt : [DEBUG    ] 2025-03-11 00:04:28,320 Detected particle type sink in domain_id=64
# yt : [DEBUG    ] 2025-03-11 00:04:28,322 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,323 Detected particle type io in domain_id=64
# yt : [DEBUG    ] 2025-03-11 00:04:28,325 Reading domain AMR   64 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,340 Detected fluid type gravity in domain_id=65
# yt : [DEBUG    ] 2025-03-11 00:04:28,341 Detected fluid type ramses-rt in domain_id=65
# yt : [DEBUG    ] 2025-03-11 00:04:28,342 Detected fluid type ramses in domain_id=65
# yt : [DEBUG    ] 2025-03-11 00:04:28,343 Detected particle type sink in domain_id=65
# yt : [DEBUG    ] 2025-03-11 00:04:28,344 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,345 Detected particle type io in domain_id=65
# yt : [DEBUG    ] 2025-03-11 00:04:28,347 Reading domain AMR   65 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,363 Detected fluid type gravity in domain_id=66
# yt : [DEBUG    ] 2025-03-11 00:04:28,364 Detected fluid type ramses-rt in domain_id=66
# yt : [DEBUG    ] 2025-03-11 00:04:28,364 Detected fluid type ramses in domain_id=66
# yt : [DEBUG    ] 2025-03-11 00:04:28,365 Detected particle type sink in domain_id=66
# yt : [DEBUG    ] 2025-03-11 00:04:28,367 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,368 Detected particle type io in domain_id=66
# yt : [DEBUG    ] 2025-03-11 00:04:28,369 Reading domain AMR   66 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,451 Detected fluid type gravity in domain_id=67
# yt : [DEBUG    ] 2025-03-11 00:04:28,453 Detected fluid type ramses-rt in domain_id=67
# yt : [DEBUG    ] 2025-03-11 00:04:28,454 Detected fluid type ramses in domain_id=67
# yt : [DEBUG    ] 2025-03-11 00:04:28,454 Detected particle type sink in domain_id=67
# yt : [DEBUG    ] 2025-03-11 00:04:28,456 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,458 Detected particle type io in domain_id=67
# yt : [DEBUG    ] 2025-03-11 00:04:28,460 Reading domain AMR   67 (3.780e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,478 Detected fluid type gravity in domain_id=68
# yt : [DEBUG    ] 2025-03-11 00:04:28,479 Detected fluid type ramses-rt in domain_id=68
# yt : [DEBUG    ] 2025-03-11 00:04:28,480 Detected fluid type ramses in domain_id=68
# yt : [DEBUG    ] 2025-03-11 00:04:28,482 Detected particle type sink in domain_id=68
# yt : [DEBUG    ] 2025-03-11 00:04:28,484 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,485 Detected particle type io in domain_id=68
# yt : [DEBUG    ] 2025-03-11 00:04:28,487 Reading domain AMR   68 (1.800e+03, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,508 Detected fluid type gravity in domain_id=69
# yt : [DEBUG    ] 2025-03-11 00:04:28,510 Detected fluid type ramses-rt in domain_id=69
# yt : [DEBUG    ] 2025-03-11 00:04:28,511 Detected fluid type ramses in domain_id=69
# yt : [DEBUG    ] 2025-03-11 00:04:28,512 Detected particle type sink in domain_id=69
# yt : [DEBUG    ] 2025-03-11 00:04:28,516 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,517 Detected particle type io in domain_id=69
# yt : [DEBUG    ] 2025-03-11 00:04:28,520 Reading domain AMR   69 (6.720e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,540 Detected fluid type gravity in domain_id=70
# yt : [DEBUG    ] 2025-03-11 00:04:28,541 Detected fluid type ramses-rt in domain_id=70
# yt : [DEBUG    ] 2025-03-11 00:04:28,542 Detected fluid type ramses in domain_id=70
# yt : [DEBUG    ] 2025-03-11 00:04:28,544 Detected particle type sink in domain_id=70
# yt : [DEBUG    ] 2025-03-11 00:04:28,549 Reading part file descriptor /Users/lamoreau/python/Aether Spectroscopy/output_00273/sink_file_descriptor.txt.
# yt : [DEBUG    ] 2025-03-11 00:04:28,551 Detected particle type io in domain_id=70
# yt : [DEBUG    ] 2025-03-11 00:04:28,553 Reading domain AMR   70 (6.720e+02, 0.000e+00)
# yt : [DEBUG    ] 2025-03-11 00:04:28,572 Detected fluid type gravity in domain_id=71
# ...
# yt : [DEBUG    ] 2025-03-11 00:04:44,148 Succeeded with ('deposit', 'nbody_nn_velocity_x') (needs {('nbody', 'particle_velocity_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y'), ('nbody', 'particle_mass'), ('nbody', 'particle_position_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,149 Succeeded with ('nbody', 'particle_ones') (needs {('nbody', 'particle_position_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,155 Succeeded with ('nbody', 'particle_angular_momentum_y') (needs {('nbody', 'particle_velocity_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_z'), ('nbody', 'particle_mass'), ('nbody', 'particle_position_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,187 Succeeded with ('nbody', 'particle_position_relative_z') (needs {('nbody', 'particle_position_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,198 Succeeded with ('nbody', 'particle_position_cylindrical_radius') (needs {('nbody', 'particle_position_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,199 Succeeded with ('nbody', 'particle_velocity_magnitude') (needs {('nbody', 'particle_velocity_z'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,201 Succeeded with ('nbody', 'relative_particle_velocity') (needs {('nbody', 'particle_velocity_z'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,212 Succeeded with ('nbody', 'particle_velocity_spherical_theta') (needs {('nbody', 'particle_velocity_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_z'), ('nbody', 'particle_position_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,213 Succeeded with ('nbody', 'relative_particle_velocity_y') (needs {('nbody', 'particle_velocity_z'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,214 Succeeded with ('nbody', 'particle_velocity_relative_x') (needs {('nbody', 'particle_velocity_z'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,218 Succeeded with ('deposit', 'nbody_nn_velocity_y') (needs {('nbody', 'particle_position_z'), ('nbody', 'particle_position_y'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_mass'), ('nbody', 'particle_position_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,219 Succeeded with ('nbody', 'particle_mass') (needs {('nbody', 'particle_mass')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,221 Succeeded with ('nbody', 'particle_angular_momentum_x') (needs {('nbody', 'particle_velocity_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_z'), ('nbody', 'particle_mass'), ('nbody', 'particle_position_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,222 Succeeded with ('nbody', 'particle_velocity_y') (needs {('nbody', 'particle_velocity_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,223 Succeeded with ('nbody', 'particle_position_x') (needs {('nbody', 'particle_position_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,226 Succeeded with ('nbody', 'particle_position_relative_y') (needs {('nbody', 'particle_position_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,228 Succeeded with ('nbody', 'mesh_id') (needs {('nbody', 'particle_position_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,230 Succeeded with ('nbody', 'relative_particle_position_x') (needs {('nbody', 'particle_position_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,232 Succeeded with ('nbody', 'particle_position_cylindrical_theta') (needs {('nbody', 'particle_position_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,247 Succeeded with ('nbody', 'particle_specific_angular_momentum_z') (needs {('nbody', 'particle_velocity_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_z'), ('nbody', 'particle_position_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,298 Succeeded with ('nbody', 'particle_position_relative_x') (needs {('nbody', 'particle_position_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,300 Succeeded with ('nbody', 'particle_position_y') (needs {('nbody', 'particle_position_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,315 Succeeded with ('nbody', 'particle_radial_velocity') (needs {('nbody', 'particle_velocity_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_z'), ('nbody', 'particle_position_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,322 Succeeded with ('deposit', 'nbody_nn_velocity_z') (needs {('nbody', 'particle_position_z'), ('nbody', 'particle_position_y'), ('nbody', 'particle_velocity_z'), ('nbody', 'particle_mass'), ('nbody', 'particle_position_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,330 Succeeded with ('deposit', 'nbody_cic_velocity_z') (needs {('nbody', 'particle_position_z'), ('nbody', 'particle_position_y'), ('nbody', 'particle_velocity_z'), ('nbody', 'particle_mass'), ('nbody', 'particle_position_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,333 Succeeded with ('deposit', 'nbody_density') (needs {('nbody', 'particle_mass'), ('nbody', 'particle_position_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,333 Succeeded with ('nbody', 'particle_velocity_relative_y') (needs {('nbody', 'particle_velocity_z'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,336 Succeeded with ('deposit', 'nbody_mass') (needs {('nbody', 'particle_mass'), ('nbody', 'particle_position_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,338 Succeeded with ('nbody', 'particle_velocity_cylindrical_theta') (needs {('nbody', 'particle_velocity_x'), ('nbody', 'particle_position_z'), ('nbody', 'particle_position_y'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_z'), ('nbody', 'particle_position_x')})
# yt : [DEBUG    ] 2025-03-11 00:04:44,339 Loading field plugins for field type: gas.
# yt : [DEBUG    ] 2025-03-11 00:04:44,342 Loaded angular_momentum (8 new fields)
# yt : [DEBUG    ] 2025-03-11 00:04:44,344 Loaded astro (22 new fields)
# yt : [DEBUG    ] 2025-03-11 00:04:44,346 Loaded cosmology (29 new fields)
# yt : [DEBUG    ] 2025-03-11 00:04:44,405 Loaded fluid (97 new fields)
# yt : [DEBUG    ] 2025-03-11 00:04:44,413 Loaded fluid_vector (129 new fields)
# yt : [DEBUG    ] 2025-03-11 00:04:44,416 Loaded geometric (142 new fields)
# yt : [DEBUG    ] 2025-03-11 00:04:44,417 Loaded local (171 new fields)
# yt : [DEBUG    ] 2025-03-11 00:04:44,419 Loaded magnetic_field (171 new fields)
# yt : [DEBUG    ] 2025-03-11 00:04:44,421 Loaded my_plugins (171 new fields)
# yt : [DEBUG    ] 2025-03-11 00:04:44,422 Loaded species (171 new fields)
# yt : [DEBUG    ] 2025-03-11 00:04:44,432 Succeeded with ('index', 'virial_radius_fraction') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,462 Raises <class 'TypeError'> during field ('gas', 'shear_mach') detection.
# yt : [DEBUG    ] 2025-03-11 00:04:44,466 Raises <class 'TypeError'> during field ('gas', 'shear_criterion') detection.
# yt : [DEBUG    ] 2025-03-11 00:04:44,469 Raises <class 'TypeError'> during field ('gas', 'shear') detection.
# yt : [DEBUG    ] 2025-03-11 00:04:44,474 Succeeded with ('index', 'cylindrical_radius') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,478 Succeeded with ('index', 'spherical_phi') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,481 Succeeded with ('index', 'cylindrical_z') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,485 Succeeded with ('index', 'morton_index') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,488 Succeeded with ('index', 'radius') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,489 Succeeded with ('index', 'zeros') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,493 Succeeded with ('index', 'spherical_radius') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,494 Succeeded with ('index', 'ones_over_dx') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,498 Succeeded with ('index', 'cylindrical_theta') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,502 Succeeded with ('index', 'spherical_theta') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,502 Succeeded with ('index', 'ones') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,503 Succeeded with ('index', 'grid_indices') (needs set())
# yt : [DEBUG    ] 2025-03-11 00:04:44,504 Succeeded with ('index', 'grid_level') (needs set())
# ---------------------------------------------------------------------------
# YTFieldNotFound                           Traceback (most recent call last)
# Cell In[9], line 120
#     117 f1 = "/Users/lamoreau/python/Aether Spectroscopy/output_00273"
#     119 ds = yt.load(f1, extra_particle_fields = epf)
# --> 120 ad = ds.all_data()
#     122 # For projections in a spherical region
#     123 sp = ds.sphere([0.49118094, 0.49275361, 0.49473726], (2000, "pc"))
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/data_objects/static_output.py:1122, in Dataset.all_data(self, find_max, **kwargs)
#    1117 def all_data(self, find_max=False, **kwargs):
#    1118     """
#    1119     all_data is a wrapper to the Region object for creating a region
#    1120     which covers the entire simulation domain.
#    1121     """
# -> 1122     self.index
#    1123     if find_max:
#    1124         c = self.find_max("density")[1]
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/data_objects/static_output.py:566, in Dataset.index(self)
#     564     oldsettings = np.geterr()
#     565     np.seterr(all="ignore")
# --> 566     self.create_field_info()
#     567     np.seterr(**oldsettings)
#     568 return self._instantiated_index
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/frontends/ramses/data_structures.py:826, in RAMSESDataset.create_field_info(self, *args, **kwa)
#     824 def create_field_info(self, *args, **kwa):
#     825     """Extend create_field_info to add the particles types."""
# --> 826     super().create_field_info(*args, **kwa)
#     827     # Register particle filters
#     828     if ("io", "particle_family") in self.field_list:
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/data_objects/static_output.py:645, in Dataset.create_field_info(self)
#     643             mylog.debug("zero common fields, skipping particle union 'nbody'")
#     644 self.field_info.setup_extra_union_fields()
# --> 645 self.field_info.load_all_plugins(self.default_fluid_type)
#     646 deps, unloaded = self.field_info.check_derived_fields()
#     647 self.field_dependencies.update(deps)
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/fields/field_info_container.py:377, in FieldInfoContainer.load_all_plugins(self, ftype)
#     375     loaded += self.load_plugin(n, ftype)
#     376     only_on_root(mylog.debug, "Loaded %s (%s new fields)", n, len(loaded))
# --> 377 self.find_dependencies(loaded)
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/fields/field_info_container.py:390, in FieldInfoContainer.find_dependencies(self, loaded)
#     389 def find_dependencies(self, loaded):
# --> 390     deps, unavailable = self.check_derived_fields(loaded)
#     391     self.ds.field_dependencies.update(deps)
#     392     # Note we may have duplicated
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/fields/field_info_container.py:602, in FieldInfoContainer.check_derived_fields(self, fields_to_check)
#     599 fi = self[field]
#     600 try:
#     601     # fd: field detector
# --> 602     fd = fi.get_dependencies(ds=self.ds)
#     603 except blacklist as err:
#     604     print(f"{err.__class__} raised for field {field}")
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/fields/derived_field.py:251, in DerivedField.get_dependencies(self, *args, **kwargs)
#     247 """
#     248 This returns a list of names of fields that this field depends on.
#     249 """
#     250 e = FieldDetector(*args, **kwargs)
# --> 251 e[self.name]
#     252 return e
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/fields/field_detector.py:127, in FieldDetector.__missing__(self, item)
#     125             vv = finfo(self)
#     126     if not permute_params:
# --> 127         vv = finfo(self)
#     128 except NeedsGridType as exc:
#     129     ngz = exc.ghost_zones
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/fields/derived_field.py:292, in DerivedField.__call__(self, data)
#     287     raise RuntimeError(
#     288         "Something has gone terribly wrong, _function is NullFunc "
#     289         + f"for {self.name}"
#     290     )
#     291 with self.unit_registry(data):
# --> 292     dd = self._function(self, data)
#     293 for field_name in data.keys():
#     294     if field_name not in original_fields:
#
# File ~/python/Aether Spectroscopy/BradenNebularLines/BradenNebularLines/emission.py:87, in get_line_emission.<locals>._line_emission(field, data)
#      84 interpolator=get_interpolator(idx, dens_normalized)
#      86 # Change to log values
# ---> 87 U_val = data['gas', 'ion-param'].value
#      88 N_val = data['gas', 'number_density'].value
#      89 T_val = data['gas', 'temperature'].value
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/fields/field_detector.py:127, in FieldDetector.__missing__(self, item)
#     125             vv = finfo(self)
#     126     if not permute_params:
# --> 127         vv = finfo(self)
#     128 except NeedsGridType as exc:
#     129     ngz = exc.ghost_zones
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/fields/derived_field.py:292, in DerivedField.__call__(self, data)
#     287     raise RuntimeError(
#     288         "Something has gone terribly wrong, _function is NullFunc "
#     289         + f"for {self.name}"
#     290     )
#     291 with self.unit_registry(data):
# --> 292     dd = self._function(self, data)
#     293 for field_name in data.keys():
#     294     if field_name not in original_fields:
#
# Cell In[9], line 49, in _ion_param(field, data)
#      45 pd_4 = data['ramses-rt','Photon_density_4']*p["unit_pf"]/cgs_c
#      47 photon = pd_2 + pd_3 + pd_4
# ---> 49 return photon/data['gas', 'number_density']
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/fields/field_detector.py:110, in FieldDetector.__missing__(self, item)
#     108 else:
#     109     field = item
# --> 110 finfo = self.ds._get_field_info(*field)
#     111 params, permute_params = finfo._get_needed_parameters(self)
#     112 self.field_parameters.update(params)
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/data_objects/static_output.py:858, in Dataset._get_field_info(self, ftype, fname)
#     857 def _get_field_info(self, ftype, fname=None):
# --> 858     field_info, candidates = self._get_field_info_helper(ftype, fname)
#     860     if field_info.name[1] in ("px", "py", "pz", "pdx", "pdy", "pdz"):
#     861         # escape early as a bandaid solution to
#     862         # https://github.com/yt-project/yt/issues/3381
#     863         return field_info
#
# File ~/anaconda3/lib/python3.10/site-packages/yt/data_objects/static_output.py:978, in Dataset._get_field_info_helper(self, ftype, fname)
#     976             self._last_finfo = self.field_info[(ftype, fname)]
#     977             return self._last_finfo, candidates
# --> 978 raise YTFieldNotFound(field=INPUT, ds=self)
#
# YTFieldNotFound: Could not find field ('gas', 'number_density') in info_00273.

# %%
sp = ds.sphere([0.49118094, 0.49275361, 0.49473726], (700, "pc"))

# %%
lines=["H1_6562.80A","O1_1304.86A","O1_6300.30A","O2_3728.80A","O2_3726.10A","O3_1660.81A",
       "O3_1666.15A","O3_4363.21A","O3_4958.91A","O3_5006.84A", "He2_1640.41A","C2_1335.66A",
       "C3_1906.68A","C3_1908.73A","C4_1549.00A","Mg2_2795.53A","Mg2_2802.71A","Ne3_3868.76A",
       "Ne3_3967.47A","N5_1238.82A","N5_1242.80A","N4_1486.50A","N3_1749.67A","S2_6716.44A","S2_6730.82A"] #
line_sums = []  # Start with an empty Python list
print(ds.field_info["gas", "intensity_H1_6562.80A"].get_source())
for line in enumerate(lines):
    wave_unmod = line[1].split("_")[-1]
    wavelength = wave_unmod[:-1]
    intensitys = sp.quantities.total_quantity(("gas", f"intensity_{line[1]}"))
    line_sums.append((float(intensitys), float(wavelength), f"intensity_{line[1]}"))  # Append the tuple
#sp.quantities. ###find the temperature of the gas
#avg_temp = sp.quantities.weighted_average_quantity(["gas", "Temperature"])
line_sums_array = np.array(line_sums)  # Convert to a NumPy array if needed
print(line_sums_array)
#print(sp.quantities.total_quantity(("gas","intensity_O1_1304.86A")))
# Out:
#     def _line_emission(field, data):
#         interpolator=get_interpolator(idx, dens_normalized)
#
#         # Change to log values
#         U_val = data['gas', 'ion-param'].value
#         N_val = data['gas', 'number_density'].value
#         T_val = data['gas', 'temperature'].value
#
#         # Cut off negative temperatures
#         T_val = np.where(T_val < 0.0, 10e-4, T_val)
#
#         U = np.log10(U_val)
#         N = np.log10(N_val)
#         T = np.log10(T_val)
#
#         # Adjust log values to within bounds supported by
#         # interpolation table
#         Uadj = np.where(U < minU, minU, U)
#         Uadj = np.where(Uadj > maxU, maxU, Uadj)
#
#         Nadj = np.where(N < minN, minN, N)
#         Nadj = np.where(Nadj > maxN, maxN, Nadj)
#
#         Tadj = np.where(T < minT, minT, T)
#         Tadj = np.where(Tadj > maxT, maxT, Tadj)
#
#         tup = np.stack((Uadj, Nadj, Tadj), axis=-1)
#
#         size  = Nadj.size
#         # Testing with constant U, T -> density variation
#         #tup = np.stack(([0.0]*size, Nadj, [5.0]*size), axis=-1)
#
#         # Return interpolated values weighted by metallicity
#         # for non-Hydrogen and Helium lines
#         interp_val = interpolator(tup)
#
#         #if idx not in [0, 10]:
#         #   interp_val = interp_val*data['gas', 'metallicity']
#
#         if dens_normalized:
#            interp_val = interp_val*data['gas', 'number_density']**2
#         else:
#            interp_val = interp_val*data['gas', 'number_density']/data['gas', 'number_density']
#
#         return interp_val
#
# [['1.8345744278364308e-11' '6562.8' 'intensity_H1_6562.80A']
#  ['3.439171954738253e-14' '1304.86' 'intensity_O1_1304.86A']
#  ['8.00608022279155e-20' '6300.3' 'intensity_O1_6300.30A']
#  ['2.7019299422959686e-18' '3728.8' 'intensity_O2_3728.80A']
#  ['1.8427295425956582e-18' '3726.1' 'intensity_O2_3726.10A']
#  ['5.282999350749038e-18' '1660.81' 'intensity_O3_1660.81A']
#  ['1.5471301927765878e-17' '1666.15' 'intensity_O3_1666.15A']
#  ['1.1474651136047718e-17' '4363.21' 'intensity_O3_4363.21A']
#  ['2.869647209191891e-17' '4958.91' 'intensity_O3_4958.91A']
#  ['8.561827834518495e-17' '5006.84' 'intensity_O3_5006.84A']
#  ['5.25125969232443e-21' '1640.41' 'intensity_He2_1640.41A']
#  ['2.4647007910113316e-13' '1335.66' 'intensity_C2_1335.66A']
#  ['1.1260858177300193e-15' '1906.68' 'intensity_C3_1906.68A']
#  ['1.3265771946464748e-15' '1908.73' 'intensity_C3_1908.73A']
#  ['1.7960574082579068e-23' '1549.0' 'intensity_C4_1549.00A']
#  ['1.1077215740076076e-12' '2795.53' 'intensity_Mg2_2795.53A']
#  ['5.530327984815049e-13' '2802.71' 'intensity_Mg2_2802.71A']
#  ['2.6930235360734774e-18' '3868.76' 'intensity_Ne3_3868.76A']
#  ['8.17373487113635e-19' '3967.47' 'intensity_Ne3_3967.47A']
#  ['3.2686463275470045e-20' '1238.82' 'intensity_N5_1238.82A']
#  ['1.63065851759312e-20' '1242.8' 'intensity_N5_1242.80A']
#  ['2.7729938053983845e-20' '1486.5' 'intensity_N4_1486.50A']
#  ['5.041895912785661e-18' '1749.67' 'intensity_N3_1749.67A']
#  ['1.883446797149045e-18' '6716.44' 'intensity_S2_6716.44A']
#  ['3.42755469781368e-18' '6730.82' 'intensity_S2_6730.82A']]

# %%
x_vals = line_sums_array[:,1].astype(float)
y_vals = line_sums_array[:,0].astype(float)
plt.plot(x_vals, y_vals, marker = "o", color = "blue",linestyle = " ")
plt.yscale("linear")
#plt.ylim([min(line_sums[:,0]), max(line_sums[:,0])])
plt.xlim([min(x_vals)-100, max(x_vals)+100])
plt.xlabel(r"Wavelength $(\AA)$")
plt.ylabel(r"Intensity $\left(\frac{1}{cm^6}?\right)$")
plt.title("Intensity v. Wavelength for different lines")
# Out:
# Text(0.5, 1.0, 'Intensity v. Wavelength for different lines')

# %%
import scipy
fig, ax = plt.subplots(1)
x = np.linspace(-4,4,21)
mean = 0
sigma = 1
y = scipy.stats.norm.pdf(x, mean, sigma) 
ax.scatter(x,y)
#σ = (√(kT/m)) / c ### this will be the formula I use for determining sigma for each line

# %%
def gaussian(x, area, mean, std): #this should already exist look these things up!!!!
    return area * (1 / (std * np.sqrt(2 * np.pi))) * np.exp(-(x - mean)**2 / (2 * std**2))
sigma = 20 #arbitrary value for now
wavelength = (min(x_vals)-100, max(x_vals)+100, 3000)
#how do we determine sigma
#how do we set this up so we can add gaussians together
y_tot = np.zeros(70000) #array for storing y values
x = np.linspace(500,7500, 70000) #wavelength range
for i in range(len(x_vals)):
    y = gaussian(x, y_vals[i], x_vals[i], sigma) # applies the gaussian for one peak over x array to obtain y values
    center_val = gaussian(x_vals[i], y_vals[i], x_vals[i], sigma)
    print(x_vals[i])
    #print(center_val/y_vals[i[0]])
    y_tot = y_tot+y 
    #print(int(np.round(x_vals[i[0]])))
    #print(x_vals[i[0]], y_tot[int(np.round(x_vals[i[0]]))-500]) #prints wavelength and gaussian peak at that point
#gaus_vals = gaussian
plt.plot(x,y_tot, marker = " ", color = "tab:orange", linestyle = "-")
plt.yscale("linear")
#plt.ylim(0,10**-31)
#plt.xlim(1050,1150)
plt.xlabel(r"Wavelength $(\AA)$")
plt.ylabel(r"Intensity $\left(\frac{1}{cm^6}?\right)$")
plt.title(r"Emission lines using gaussians ($\sigma = 20$)")
#plt.savefig("Gaussian_emission_plot")
plt.show()



""" gaussian_array = []
#problem with i as an array?
for i in enumerate(np.zeros(len(x_vals))):
    print(i)
    gaussian_array[i] = gaussian(wavelength, y_vals[i], x_vals[i], sigma)
gaussian_array = np.array(gaussian_array)
#gaussian for each emission
#add gaussian functions
#apply over linspace of wavelength """
# Out:
# 6562.8
# 1304.86
# 6300.3
# 3728.8
# 3726.1
# 1660.81
# 1666.15
# 4363.21
# 4958.91
# 5006.84
# 1640.41
# 1335.66
# 1906.68
# 1908.73
# 1549.0
# 2795.53
# 2802.71
# 3868.76
# 3967.47
# 1238.82
# 1242.8
# 1486.5
# 1749.67
# 6716.44
# 6730.82
# ' gaussian_array = []\n#problem with i as an array?\nfor i in enumerate(np.zeros(len(x_vals))):\n    print(i)\n    gaussian_array[i] = gaussian(wavelength, y_vals[i], x_vals[i], sigma)\ngaussian_array = np.array(gaussian_array)\n#gaussian for each emission\n#add gaussian functions\n#apply over linspace of wavelength '

# %%
print(ds.current_redshift)
x_rshift = x * (ds.current_redshift+1)
fig, axs = plt.subplots(2,1)
axs[0].plot(x_rshift,y_tot, marker = " ", color = "tab:red", linestyle = "-")
axs[1].plot(x,y_tot, marker = " ", color = "tab:red", linestyle = "-")

axs[0].set_yscale("linear")
axs[1].set_yscale("linear")

#plt.ylim(0,10**-31)
#plt.xlim(1050,1150)
for ax in axs.flat:
    ax.set(xlabel = r"Wavelength $(\AA)$", ylabel = r"Intensity $\left(\frac{1}{cm^6}?\right)$")
fig.suptitle(r"Emission lines using gaussians ($\sigma = 20$)")
#plt.savefig("Gaussian_emission_plot")
### Don't know how this works
plt.show()
print(axs.flat)
# Out:
# 12.171087046255657
# <numpy.flatiter object at 0x7faddb136a00>

# %% [markdown]
# No more log scale intensity! We need to care about signal to noise when we are looking at our spectra
#
# The next process:
#
# We want to add a bunch of temperature corrected gaussians together, normalize them back to one, maybe weight them by something

# %% [markdown]
#  1. Previous Graduate student made images with SKIRT software and some lines like Halpha, this is DUST stuff, tried to make things look like the ORION nebula
#  * SKIRT can model the diffusion process, if we can do star by star this starts to matter
#  * Monte Carlo: lots of different trials, use that data to determine probabilistically what you will observe.
#
#  2. Spectral Resolution of JWST (it is quite low so we have to choose what we want to model carefully)
#  * How JWST makes it's spectra (bin sizes kind of things)
#  * Figure out how bins change with redshift

# %%
plot1 = yt.PhasePlot(
    sp, ('gas', 'ion-param2'), ("gas", "temperature"), [("gas", "intensity_H1_6562.80A")], weight_field=None
)

plot2 = yt.PhasePlot(
    sp, ("gas", "number_density"), ("gas", "ion-param2"), [("gas", "intensity_H1_6562.80A")], weight_field=None
)

plot3 = yt.PhasePlot(
    sp, ("gas", "temperature"), ("gas", "number_density"), [("gas", "intensity_H1_6562.80A")], weight_field=None
)

# %%
titles = ["Temp_Ion-param2", "Ion-param2_numden", "numden_Temp"]
plots = [plot1, plot2, plot3]
for i in range(len(titles)):
    plots[i].annotate_title(titles[i])
    plots[i].show()
    #plots[i].save(titles[i])
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
plot1.save("")
# Out:
# ['.png_2d-Profile_ion-param2_temperature_intensity_H1_6562.80A']

# %%
intvint = yt.PhasePlot(
    sp, ("gas", "intensity_H1_6562.80A"), ("gas", "intensity_O3_4363.21A"), [("gas", "temperature")], weight_field=None
)

# %%
intvint.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
intvint2 = yt.PhasePlot(
    sp, ("gas", "intensity_H1_6562.80A"), ("gas", "intensity_O2_3726.10A"), [("gas", "temperature")], weight_field=None
)

# %%
intvint2.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
plot1 = yt.PhasePlot(
    sp2, ('gas', 'ion-param2'), ("gas", "temperature"), [("gas", "intensity_H1_6562.80A")], weight_field=None
)

plot2 = yt.PhasePlot(
    sp2, ("gas", "number_density"), ("gas", "ion-param2"), [("gas", "intensity_H1_6562.80A")], weight_field=None
)

plot3 = yt.PhasePlot(
    sp2, ("gas", "temperature"), ("gas", "number_density"), [("gas", "intensity_H1_6562.80A")], weight_field=None
)
# Out:
# /Users/lamoreau/python/Aether Spectroscopy/BradenNebularLines/BradenNebularLines/emission.py:96: RuntimeWarning: divide by zero encountered in log10
#   T = np.log10(T_val)

# %%
titles = ["Temp_Ion-param2", "Ion-param2_numden", "numden_Temp"]
plots = [plot1, plot2, plot3]
for i in range(len(titles)):
    plots[i].annotate_title(titles[i])
    plots[i].show()
    #plots[i].save(titles[i])
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
plot1 = yt.PhasePlot(
    sp3, ('gas', 'ion-param2'), ("gas", "temperature"), [("gas", "intensity_H1_6562.80A")], weight_field=None
)

plot2 = yt.PhasePlot(
    sp3, ("gas", "number_density"), ("gas", "ion-param2"), [("gas", "intensity_H1_6562.80A")], weight_field=None
)

plot3 = yt.PhasePlot(
    sp3, ("gas", "temperature"), ("gas", "number_density"), [("gas", "intensity_H1_6562.80A")], weight_field=None
)

# %%
titles = ["Temp_Ion-param2", "Ion-param2_numden", "numden_Temp"]
plots = [plot1, plot2, plot3]
for i in range(len(titles)):
    plots[i].annotate_title(titles[i])
    plots[i].show()
    #plots[i].save(titles[i])
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
print(sp3[("gas", "temperature")])
#plt.figure()
plot = yt.ProfilePlot(sp3, ("gas", "temperature"), [("gas", "number_density")], weight_field=None)
# Out:
# [ 673437.04280745  999025.89946466  757847.49848731 ... 1604064.22188349
#  2039294.07362091 1703462.51741291] K

# %%
plot.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# somewhere in yt.load, you specify cell_fields, needed this to specify photons
# misbehaving because the file in our code is not in the correct format for the yt code currently, file is not read correctly
# format specified on the website, first line is the version, then other stuff after that
